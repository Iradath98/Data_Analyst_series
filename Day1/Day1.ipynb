# %% [markdown]
# # Python - Data Types and Variables

# %%
 1+3
# Out:
# 4

# %%
type (123)
# Out:
# int

# %%
type (1.23)
# Out:
# float

# %%
type ("123")
# Out:
# str

# %%
type ('A')
# Out:
# str

# %%
type ("false")
# Out:
# str

# %%
type (True)
# Out:
# bool

# %%
num
# Out:
# [1, 2, 6, 7]

# %%
type (num)
# Out:
# list

# %%
len (num)
# Out:
# 4

# %%
numb[2]
# Out:
# 6

# %%
names[2]
# Out:
# 'GHI'

# %%
act[2]
# Out:
# True
